# %%
import os
from math import isnan
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def ptest(list1, list2):
    '''P-Test to see if difference between 2 dataset is significant at 99% C.I.'''
    var1 = np.var(list1)
    var2 = np.var(list2)
    std12 = np.sqrt(var1+var2)
    obs = np.mean(list1)-np.mean(list2)
    z = abs(obs/std12)
    if z>3:
        return True
    else:
        return False
    
def corr(list1, list2):
    '''Find correlation between 2 datasets. Removes NaNs'''
    #Remove Nan:
    new_list1 = []
    new_list2 = []
    for i1,i2 in zip(list1,list2):
        if (isnan(i1)==False) & (isnan(i2)==False):
            new_list1.append(i1)
            new_list2.append(i2)
    cov = np.cov([new_list1,new_list2])[0][1]
    std1 = np.std(new_list1)
    std2 = np.std(new_list2)
    corr = cov/(std1*std2)
    return corr

# %%
path = '/home/sadat/Desktop/Hackathon/Hack-a-thon_Dataset_2016.xlsx'
xl = pd.ExcelFile(path)
names = xl.sheet_names
names
# Out:
# [u'Basic Metadata',
#  u'Data Notes',
#  u'Useful Links',
#  u'Lenses of Health Equity',
#  u'Critical Pathways',
#  u'Trended 3-4-50 Chronic Disease',
#  u'Asthma_Death_2010-2013',
#  u'Asthma_EDD_2010-2013',
#  u'Asthma_Hosp_2010-2013',
#  u'CHD_Death_2010-2013',
#  u'CHD_EDD_2010-2013',
#  u'CHD_Hosp_2010-2013',
#  u'COPD_Death_2010-2013',
#  u'COPD_EDD_2010-2013',
#  u'COPD_Hosp_2010-2013',
#  u'Diabetes_Death_2010-2013',
#  u'Diabetes_EDD_2010-2013',
#  u'Diabetes_Hosp_2010-2013',
#  u'Overall Cancer_Death_2010-2013',
#  u'Overall Cancer_EDD_2010-2013',
#  u'Overall Cancer_Hosp_2010-2013',
#  u'Stroke_Death_2010-2013',
#  u'Stroke_EDD_2010-2013',
#  u'Stroke_Hosp_2010-2013',
#  u'Behaviors Data ',
#  u'Age, Gender, RaceEthnicity',
#  u'Demographics and Economics',
#  u'SES_Urbanicity Pop for Rate',
#  u'Population Forecasts']

# %%
#Death data

death_df = pd.read_excel(path, sheetname='Trended 3-4-50 Chronic Disease')
death_df = death_df[['Geography','Total Deaths (All Causes)','Stroke Deaths',
         'CHD Deaths','Diabetes Deaths','COPD Deaths','Asthma Deaths','Cancer Deaths']]
death_df.head()
# Out:
#                 Geography  Total Deaths (All Causes)  Stroke Deaths  \
# 0       San Diego County                       19621           1578
# 1          Central Region                       3077            244
# 2       Central San Diego                       1225             88
# 3                Mid-City                        992             92
# 4  Southeastern San Diego                        860             64
#
#    CHD Deaths  Diabetes Deaths  COPD Deaths  Asthma Deaths  Cancer Deaths
# 0        4552              481         1028             36           4724
# 1         703              110          136             10            676
# 2         289               36           57            NaN            242
# 3         227               25           47              5            227
# 4         187               49           32            NaN            207

# %%
#Behavior data

behavior_df = pd.read_excel(path, sheetname='Behaviors Data ')
behaviors = behavior_df.columns[2::]
behavior_df['Geography']=behavior_df['SRA Name']
del behavior_df['SRA Name']
behaviors
# Out:
# Index([     u'2013 Percent (adults)  volunteered for a charitable org in last 12 months',
#        u'2013 Percent (adults)  voted in federal/state/local election in last 12 months',
#                     u'2013 Percent (adults)  affiliated with Democratic political party',
#                     u'2013 Percent (adults)  affiliated with Republican political party',
#              u'2013 Percent (adults)  affiliated with Independent or no political party',
#                                 u'2013 Percent (adults)  have interest checking account',
#                             u'2013 Percent (adults)  have non-interest checking account',
#                                           u'2013 Percent (adults)  have savings account',
#              u'2013 Percent (adults)  obtained medical insurance: through place of work',
#                    u'2013 Percent (adults)  obtained medical insurance: through a union',
#                           u'2013 Percent (adults)  obtained medical insurance: Medicaid',
#                           u'2013 Percent (adults)  obtained medical insurance: Medicare',
#                             u'2013 Percent (adults)  Exercise at home 2+ times per week',
#                             u'2013 Percent (adults)  Exercise at club 2+ times per week',
#              u'2013 Percent (adults)  Exercise at other facility (not club) 2+ times/wk',
#                                     u'2013 Percent (adults)  Presently controlling diet',
#                                   u'2013 Percent (adults)  Diet control for weight loss',
#              u'2013 Percent (adults)  Buy foods specifically labeled as natural/organic',
#             u'2013 Percent (adults)  Used vitamins/dietary supplements in last 6 months',
#                    u'2013 Percent (adults)  Visited doctor in last 12 months: 1-2 times',
#                    u'2013 Percent (adults)  Visited doctor in last 12 months: 3-5 times',
#                     u'2013 Percent (adults)  Visited doctor in last 12 months: 6+ times',
#                              u'2013 Percent (adults)  Used prescription drug for asthma',
#                  u'2013 Percent (adults)  Used prescription drug for backache/back pain',
#                          u'2013 Percent (adults)  Used prescription drug for depression',
#              u'2013 Percent (adults)  Used prescr drug for diabetes (insulin dependent)',
#             u'2013 Percent (adults)  Used prescr drug for diabetes (non-insulin depend)',
#               u'2013 Percent (adults)  Used prescription drug for eczema/skin itch/rash',
#               u'2013 Percent (adults)  Used prescription drug for heartburn/acid reflux',
#                 u'2013 Percent (adults)  Used prescription drug for high blood pressure',
#                    u'2013 Percent (adults)  Used prescription drug for high cholesterol',
#                   u'2013 Percent (adults)  Used prescription drug for migraine headache',
#                 u'2013 Percent (adults)  Used prescr drug for sinus congestion/headache',
#             u'2013 Percent (adults)  Used prescription drug for urinary tract infection',
#                            u'2013 Percent (adults)  Smoked cigarettes in last 12 months',
#                   u'2013 Percent (adults)  Smoked 9+ packs of cigarettes in last 7 days',
#                    u'2013 Percent (adults)  Rarely check food ingredients before buying',
#              u'2013 Percent (adults)  Occasionally check food ingredients before buying',
#                u'2013 Percent (adults)  Frequently check food ingredients before buying',
#                   u'2013 Percent (adults)  Usually check food ingredients before buying',
#                             u'2013 Percent (adults)  Spend 6+ hours exercising per week',
#                            u'2013 Percent (adults)  Spend 3-5 hours exercising per week',
#                            u'2013 Percent (adults)  Spend 1-2 hours exercising per week',
#                 u'2013 Percent (adults)  Spend no time exercising during a typical week',
#                      u'2013 Percent (adults)  Usually follow a regular exercise routine',
#                   u'2013 Percent (adults)  Frequently follow a regular exercise routine',
#                 u'2013 Percent (adults)  Occasionally follow a regular exercise routine',
#                       u'2013 Percent (adults)  Rarely follow a regular exercise routine',
#                    u'2013 Percent (adults)  Spent at fast food/drive-in last 6 mo: <$11',
#                 u'2013 Percent (adults)  Spent at fast food/drive-in last 6 mo: $11-$20',
#                 u'2013 Percent (adults)  Spent at fast food/drive-in last 6 mo: $21-$40',
#                 u'2013 Percent (adults)  Spent at fast food/drive-in last 6 mo: $41-$50',
#                u'2013 Percent (adults)  Spent at fast food/drive-in last 6 mo: $51-$100',
#               u'2013 Percent (adults)  Spent at fast food/drive-in last 6 mo: $101-$200',
#                   u'2013 Percent (adults)  Spent at fast food/drive-in last 6 mo: $201+'],
#       dtype='object')

# %%
#Merge dataframes

df = death_df.merge(behavior_df, how='left', on='Geography')
df.head()
# Out:
#                 Geography  Total Deaths (All Causes)  Stroke Deaths  \
# 0       San Diego County                       19621           1578
# 1          Central Region                       3077            244
# 2       Central San Diego                       1225             88
# 3                Mid-City                        992             92
# 4  Southeastern San Diego                        860             64
#
#    CHD Deaths  Diabetes Deaths  COPD Deaths  Asthma Deaths  Cancer Deaths  \
# 0        4552              481         1028             36           4724
# 1         703              110          136             10            676
# 2         289               36           57            NaN            242
# 3         227               25           47              5            227
# 4         187               49           32            NaN            207
#
#    SRA Number   \
# 0          NaN
# 1          NaN
# 2          NaN
# 3            6
# 4          NaN
#
#    2013 Percent (adults)  volunteered for a charitable org in last 12 months  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                            0.19604
# 4                                                NaN
#
#                                   ...                                   \
# 0                                 ...
# 1                                 ...
# 2                                 ...
# 3                                 ...
# 4                                 ...
#
#    2013 Percent (adults)  Frequently follow a regular exercise routine  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                            0.35714
# 4                                                NaN
#
#    2013 Percent (adults)  Occasionally follow a regular exercise routine  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                            0.23056
# 4                                                NaN
#
#    2013 Percent (adults)  Rarely follow a regular exercise routine  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                            0.09965
# 4                                                NaN
#
#    2013 Percent (adults)  Spent at fast food/drive-in last 6 mo: <$11  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                            0.04963
# 4                                                NaN
#
#    2013 Percent (adults)  Spent at fast food/drive-in last 6 mo: $11-$20  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                            0.06922
# 4                                                NaN
#
#    2013 Percent (adults)  Spent at fast food/drive-in last 6 mo: $21-$40  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                            0.10677
# 4                                                NaN
#
#    2013 Percent (adults)  Spent at fast food/drive-in last 6 mo: $41-$50  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                            0.06653
# 4                                                NaN
#
#    2013 Percent (adults)  Spent at fast food/drive-in last 6 mo: $51-$100  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                             0.1518
# 4                                                NaN
#
#    2013 Percent (adults)  Spent at fast food/drive-in last 6 mo: $101-$200  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                            0.11652
# 4                                                NaN
#
#    2013 Percent (adults)  Spent at fast food/drive-in last 6 mo: $201+
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                            0.10031
# 4                                                NaN
#
# [5 rows x 64 columns]

# %%
#Check if correlation is greater than 0.5

deaths = ['Total Deaths (All Causes)','Stroke Deaths','CHD Deaths','Diabetes Deaths',
          'COPD Deaths','Asthma Deaths','Cancer Deaths']

for d in deaths:
    print 'Factors for '+d+':'
    for b in behaviors:
        c = corr(df[d],df[b])
        if c>0.4: #We cant get any correlation if we check for >0.5
            print b, ':\t%.2f'%c 
        else:
            continue
    print '\n'
# Out:
# Factors for Total Deaths (All Causes):
# 2013 Percent (adults)  Frequently check food ingredients before buying :	0.47
#
#
# Factors for Stroke Deaths:
# 2013 Percent (adults)  Frequently check food ingredients before buying :	0.43
#
#
# Factors for CHD Deaths:
# 2013 Percent (adults)  Frequently check food ingredients before buying :	0.45
#
#
# Factors for Diabetes Deaths:
# 2013 Percent (adults)  Frequently check food ingredients before buying :	0.43
#
#
# Factors for COPD Deaths:
# 2013 Percent (adults)  Frequently check food ingredients before buying :	0.42
#
#
# Factors for Asthma Deaths:
# 2013 Percent (adults)  obtained medical insurance: Medicaid :	0.44
#
#
# Factors for Cancer Deaths:
# 2013 Percent (adults)  Buy foods specifically labeled as natural/organic :	0.41
# 2013 Percent (adults)  Frequently check food ingredients before buying :	0.48
